# %% [markdown]
# # Baseball Case Study

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Given features - Input & Output

# %%
#import Baseball.csv file
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Baseball statistics play an important role in evaluating the progress of a player or team. Describing the feature according to different diffirent feature.

# %% [markdown]
# 1. Batting statistics.
#
# R – Runs scored: number of times a player crosses home plate.
#
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# H – Hit: reaching base because of a batted, fair ball without error by the defense.
#
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# PA/SO – Plate appearances per strikeout: number of times a batter strikes out to their plate appearance.
#
# 2. Baserunning statistics.
#
# SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# R – Runs scored: times reached home plate legally and safely.
#
# 3. Pitching statistics.
#
# BB – Base on balls (also called a "walk"): times pitching four balls, allowing the batter to take first base.
#
# CG – Complete game: number of games where player was the only pitcher for his team.
#
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls.
#
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense
#     benefits as a result
#     .
# SHO – Shutout: number of complete games pitched with no runs allowed.
#
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without
#     surrendering the lead.
#
# RA – Run average: number of runs allowed times nine divided by innings pitched.
#
# HR (or HRA) – Home runs allowed: total home runs allowed.
#
#
# W – Win: number of games where pitcher was pitching while his team took the lead and went on to win, also the
# starter needs to pitch at least 5 innings of work (also related: winning percentage)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# We get to know that,
#
# 1. No missing value in any features.
# 2. 30 row with 17 columns in this datasdet.
# 3. All features are numeric only ERA is folat numeric type and other features are int data type.
# 4. Output: Number of predicted wins (W).
# 5. For predicting the number of wins a baseball team will attain -- based on the given input features, a linear regression approach is neccessary.

# %% [markdown]
# # To check missing value

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # Summary statistics

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# we get to know that,
#
# 1. min value in all features less than 50% of all feature.
#
# 2. Standard deviation in SO is maximum and difference between 75% and max is also high.
#
# 3. Difference between 75% and max is normally in all feature not more .

# %%
#to check correlation
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),cmap='rocket',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We find that,
#
# 1. Light shades are highly correlated
#
# 2. W are higly negatively correlated with RA,ER,ERA and higly positive correlated with SV.
#
# 3. W are postively correlated with SV,SHO,BB,HR,2B,R.
#
# 4. RA,ER,ERA higly postive correlated with each other.
#
# 5. SV and SHO both are negatively correlated with RA,ER,ERA

# %% [markdown]
# # Exploring data variable

# %%
#Univariate analysis of postive coorelated featuers
sns.set(style='whitegrid')
sns.violinplot(x='SV',data=df)
plt.title("Number of games where the pitcher enters a game led by the pitcher's team")
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(x='SHO',data=df)
plt.title("Number of complete games pitched with no runs allowed")
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(x='R',data=df)
plt.title("Runs scored: number of times a player crosses home plate")
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(x='2B',data=df)
plt.title("Double: hits on which the batter reaches second base safely without the contribution of a fielding error")
plt.show()

# %% [markdown]
# When winning changes increase some feathures value given below.
#
# 1. SV- value between 35 to 45.
#
# 2. SHO- score between 10 to 14.
#
# 3. R- score between 670 to 700.
#
# 4. 2B-score between 260 to 280.

# %%
#Univariate analysis of negatively correlated with W
sns.set(style='whitegrid')
sns.violinplot(x='RA',data=df)
plt.title("Run average: number of runs allowed times nine divided by innings pitched")
plt.show()

# %%
#Univariate analysis of negatively correlated with W
sns.set(style='whitegrid')
sns.violinplot(x='ERA',data=df)
plt.title("Earned run average")
plt.show()

# %%
#Univariate analysis of negatively correlated with W
sns.set(style='whitegrid')
sns.violinplot(x='ER',data=df)
plt.title("Earned run: number of runs that did not occur as a result of errors or passed balls")
plt.show()

# %% [markdown]
# When wining percentage decrease some feature value are draw with above negatively correlated with W.
#
# 1. RA-score 680 to 700.
#
# 2. ERA-approximately 4.
#
# 3. ER-score 630 to 650.

# %% [markdown]
# # Bivariate Analysis

# %%
# lets check the how Er is changing with respect to RA

sns.lineplot(x=df['ER'],y=df['RA'],data=df)
plt.show()
# The below graph clearly show that with increase in ER their is increase in RA too

# %%
# lets check the how W is changing with respect to ER

sns.lineplot(x=df['ER'],y=df['W'],data=df)
plt.show()
# The below graph clearly show that with decrease in ER their is increase in W

# %% [markdown]
# Bivariate Analysis of postive correlated Featuhe with w

# %%
plt.scatter(df['SV'],df['W'])
plt.show()

# %% [markdown]
# winning percentage is more when SV value is more than 42 and minimum when SV value below than 45.

# %%
plt.scatter(df['SHO'],df['W'])
plt.show()

# %%
plt.scatter(df['R'],df['W'])
plt.show()

# %%
plt.scatter(df['2B'],df['W'])
plt.show()

# %%
#Bivariate analysis of negativel coorelated feature with w
plt.scatter(df['RA'],df['W'])
plt.show()

# %% [markdown]
# when RA value is more than 670 than winning percentage is approx less than 50.
# RA value beow from 630 than winning changes increase simultaneously and approx 520 RA value is maximum.

# %%
plt.scatter(df['ER'],df['W'])
plt.show()

# %% [markdown]
# Below than 600 wining percentage increase and above from 650 W is less than 80.

# %%
plt.scatter(df['ERA'],df['W'])
plt.show()

# %% [markdown]
# 1. When ERA value less than 3.5 than winning percentage is more than 90.
#
# 2. When ERA value is more than 4.25 than winning percentage 75.

# %% [markdown]
# # Check skewness distribution

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Skewness present in R,H,HR,CG,SHO,SV,E features

# %%
#Distribution plot 
#describe() function give the summary of numeric columns
for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %%
#Lets treat the skewness
import numpy as np
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df.skew().loc[col]>0.5:
            df[col]=np.sqrt(df[col])
        if df.skew().loc[col]<-0.5:
            df[col]=np.cbrt(df[col])

# %%
#Again check skewness
df.skew()
# Out:
# W      0.047089
# R      0.968676
# AB     0.183437
# H      0.649567
# 2B    -0.230650
# 3B     0.129502
# HR     0.264948
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.311476
# SHO   -0.061761
# SV     0.410288
# E      0.763487
# dtype: float64

# %% [markdown]
# After removing skewness in R,H,E features some skewness value present.

# %%
print(df['E'].describe())
sns.countplot(df['E'])
# Out:
# count    30.000000
# mean      9.687994
# std       0.701800
# min       8.660254
# 25%       9.273618
# 50%       9.539248
# 75%       9.836133
# max      11.224972
# Name: E, dtype: float64
# <AxesSubplot:xlabel='E', ylabel='count'>

# %%
print(df['R'].describe())
sns.countplot(df['R'])
# Out:
# count    30.000000
# mean     26.211930
# std       1.099235
# min      23.937418
# 25%      25.519565
# 50%      26.248809
# 75%      26.800127
# max      29.849623
# Name: R, dtype: float64
# <AxesSubplot:xlabel='R', ylabel='count'>

# %%
print(df['H'].describe())
sns.countplot(df['H'])
# Out:
# count    30.000000
# mean     37.456345
# std       0.758091
# min      36.386811
# 25%      36.918830
# 50%      37.181984
# 75%      38.097803
# max      38.923001
# Name: H, dtype: float64
# <AxesSubplot:xlabel='H', ylabel='count'>

# %% [markdown]
# # Plotting outliers

# %%
for i in df.describe().columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# Outliers are present in some feature but in E more outliers.

# %% [markdown]
# # Removing Outliers

# %%
df1=df.copy()
df1.head()
# Out:
#     W          R    AB          H   2B  3B         HR   BB    SO   SB   RA  \
# 0  95  26.907248  5575  38.691084  300  42  11.789826  383   973  104  641
# 1  83  26.381812  5467  36.728735  277  44  12.489996  439  1264   70  700
# 2  81  25.865034  5439  37.349699  303  29  11.874342  533  1157   86  640
# 3  76  24.939928  5533  37.161808  260  27  11.661904  404  1231   68  701
# 4  74  26.248809  5605  38.923001  289  49  12.288206  455  1259   83  803
#
#     ER   ERA        CG       SHO        SV          E
# 0  601  3.73  1.414214  2.828427  7.483315   9.380832
# 1  653  4.07  1.414214  3.464102  6.708204   9.273618
# 2  584  3.67  3.316625  3.162278  6.164414   8.888194
# 3  643  3.98  2.645751  3.000000  6.082763  10.049876
# 4  746  4.64  2.645751  3.464102  5.916080   9.273618

# %%
df1.shape
# Out:
# (30, 17)

# %%
from scipy.stats import zscore

# %%
import scipy.stats as stats

# %%
z=np.array(zscore(df1))
z
# Out:
# array([[ 1.36540860e+00,  6.43360457e-01,  8.47731264e-01,
#          1.65659155e+00,  1.42017307e+00,  1.04119304e+00,
#         -7.79588836e-01, -1.53490242e+00, -2.69762957e+00,
#          9.13883291e-01, -6.66233927e-01, -5.05110079e-01,
#         -5.06955186e-01, -2.92055667e-01, -7.81873120e-01,
#          1.62988184e+00, -4.45160189e-01],
#        [ 1.97838300e-01,  1.57187245e-01, -7.11093535e-01,
#         -9.76199843e-01,  1.27403389e-01,  1.23580856e+00,
#         -2.01722201e-01, -5.36591904e-01,  1.54878442e-01,
#         -6.01825582e-01,  1.65970766e-01,  2.48929848e-01,
#          2.54597523e-01, -2.92055667e-01,  2.59566641e-01,
#          2.95192242e-01, -6.00540408e-01],
#        [ 3.24325082e-03, -3.20974401e-01, -1.11523330e+00,
#         -1.43082336e-01,  1.58879521e+00, -2.23807850e-01,
#         -7.09835826e-01,  1.13914361e+00, -8.93981893e-01,
#          1.11449182e-01, -6.80339091e-01, -7.51623132e-01,
#         -6.41346840e-01,  1.96563341e+00, -2.34918307e-01,
#         -6.41178049e-01, -1.15912252e+00],
#         -2.30134814e-01, -1.39609171e-01],
#        [-1.26162457e+00,  8.65885349e-01,  8.04430575e-01,
#          1.34356350e+00, -4.12187436e-02,  1.72234737e+00,
#          7.45902414e-01, -1.44576756e+00,  3.41124670e-01,
#          6.01825582e-01,  2.19711442e+00,  2.36604195e+00,
#          2.42726261e+00,  4.03127172e-01, -2.13910384e+00,
#         -9.24288087e-01,  8.52173851e-02]])

# %%
#Using threshold value as 3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z[5][1]
# Out:
# 3.365867919765219

# %%
df1_new=df1[(z<3).all(axis=1)]

# %%
df1_new=df1[(z<3).all(axis=1)]

# %% [markdown]
# Conclusion: 1 row detect as a Outliers.

# %%
df1=df1_new
df1.shape
# Out:
# (29, 17)

# %%
# seprating into input and output variable
x=df1.drop(['W'],axis=1)
x.shape
# Out:
# (29, 16)

# %%
y=df1['W']
y.shape
# Out:
# (29,)

# %%
# Scaling the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.95651645,  0.83008422,  1.73108753,  1.55653766,  1.01084549,
#         -0.75401669, -1.53635899, -2.72762331,  0.9059529 , -0.66451353,
#         -0.51114812, -0.51138828, -0.25354897, -0.77743601,  1.60263096,
#         -0.45432526],
#        [ 0.34416795, -0.70283074, -0.94430524,  0.20117132,  1.20891656,
#         -0.13904468, -0.49502051,  0.12189552, -0.58531515,  0.15463823,
#          0.23216082,  0.23895226, -0.25354897,  0.24747497,  0.25562074,
#         -0.60761852],
#        [-0.25808975, -1.10025314, -0.097707  ,  1.73332457, -0.2766165 ,
#         -0.67978478,  1.25294051, -0.9258657 ,  0.11645805, -0.67839746,
#         -0.75415297, -0.64380131,  2.02046293, -0.23916196, -0.68939326,
#         -1.15869812],
#        [-1.33621796,  0.23395062, -0.35386977, -0.8006212 , -0.47468758,
#         -0.86637322, -1.14585706, -0.20124579, -0.6730368 ,  0.16852216,
#          0.08921679,  0.04033271,  1.21854679, -0.50080556, -0.83128957,
#          0.50227443],
#        [ 0.18916563,  1.25589393,  2.047274  ,  0.90831897,  1.70409425,
#         -0.31628077, -0.19749523,  0.07293472, -0.01512442,  1.58468284,
#          1.56154027,  1.4968761 ,  1.21854679,  0.24747497, -1.12095571,
#         -0.60761852],
#        [ 1.81111362,  0.71653496, -0.06121744, -0.09347354, -1.26697188,
#          1.67927076,  1.64344245, -0.24041443, -0.89234092,  0.12687038,
#          0.21786641,  0.1506769 ,  0.12637187, -2.11312601,  0.63794193,
#         -0.07854614],
#        [ 0.71738804, -0.44734492, -0.55605275, -1.6256268 , -1.16793634,
#          1.82919977, -0.88552244,  0.7779703 , -1.7256966 ,  0.05745074,
#          0.1321    ,  0.19481458, -1.94400286, -0.23916196, -0.00638379,
#         -1.32059449],
#        [-0.82666901, -0.44734492, -0.31719585,  0.26010029,  0.02049011,
#          0.24113714, -0.5508065 ,  0.57233492,  0.16031888, -0.6506296 ,
#         -0.46826492, -0.48931944, -0.74867145,  0.24747497,  2.05907512,
#          0.06892863],
#        [ 1.4720245 ,  1.75267193,  1.69583863,  1.20296383,  0.11952565,
#          0.03537313,  0.23019736, -1.01399515, -0.54145432,  0.89048643,
#         -1.48774182, -1.68512163, -0.99441083,  1.2568395 , -0.15080819,
#          0.01774478,  0.12860806, -1.94400286,  0.24747497, -1.12095571,
#         -1.32059449],
#        [-2.50455231, -1.36993263, -0.72207969, -1.33098194, -1.36600741,
#         -2.32605374,  0.10003005, -1.41547375, -0.62917597,  0.98767393,
#          0.87540894,  0.9892928 ,  0.12637187, -0.23916196,  0.12536288,
#         -0.3027643 ],
#        [-1.24291038,  0.177176  , -0.48243807, -0.09347354,  0.5156678 ,
#         -1.09486732, -1.46197767,  0.21981713,  0.2041797 ,  1.66798641,
#          1.60442347,  1.6072203 , -0.74867145, -1.07196796, -1.12095571,
#          1.59861442],
#        [-0.30318083, -1.86671063, -1.00001589, -0.62383428, -0.57372311,
#          0.90158538,  1.81080042,  0.06314255, -1.06778422, -1.30317423,
#         -1.19727945, -1.15138462,  0.98394917,  2.05081361,  0.51186481,
#         -1.48460742],
#        [ 0.34416795,  0.68814765,  1.53692603,  0.84939   ,  0.71373887,
#         -0.86637322, -0.16030457, -0.90628138,  0.42348383, -0.85888852,
#         -0.56832573, -0.53345712,  1.21854679,  1.50272944, -0.27455565,
#         -1.23938684],
#        [ 0.86977224,  1.88041485,  1.67820534,  0.90831897,  1.60505871,
#         -0.20959327,  0.45334132,  0.59191925,  2.134056  ,  0.3351293 ,
#          0.31792723,  0.17274574, -0.74867145,  0.24747497,  0.12536288,
#         -0.60761852],
#        [-0.68921768, -0.84476732, -1.41047232, -0.8006212 ,  0.41663226,
#         -0.42403344, -0.7367598 ,  0.73880166, -0.05898525,  0.58504001,
#          0.26074962,  0.28308994, -0.74867145, -1.38840451, -0.27455565,
#         -0.15287821],
#        [ 1.23679265,  0.78750325,  1.41299435,  0.0243844 ,  1.70409425,
#          0.86942784, -1.44338234,  0.30794658,  0.59892713,  2.1539239 ,
#          2.31914361,  2.37962968,  0.44665996, -2.11312601, -0.97511671,
#          0.06892863]])

# %% [markdown]
# # Machine Learning Algorithm

# %%
# Model Training and Validation
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score

# ML Algorithms
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Model Export
import joblib
from joblib import dump #from joblib import load > to load .pkl file

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print('x_train.shape: ',x_train.shape,'x_test.shape: ',x_test.shape,'\ny_train.shape',y_train.shape,'y_test.shape',y_test.shape)
# Out:
# x_train.shape:  (23, 16) x_test.shape:  (6, 16)
# y_train.shape (23,) y_test.shape (6,)

# %%
#Creating function for Model Training
from sklearn.metrics import mean_squared_error, r2_score
def models(model, x_train, x_test, y_train, y_test,score,rmse):
    #Fit the algorithm on the data
    model.fit(x_train, y_train)
    
    #Predict training set:
    y_pred = model.predict(x_test)
    
    score.append(model.score(x_train,y_train))
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    
    print('\nModel Report')
    print('Score:',model.score(x_train,y_train))
    print('RMSE:',np.sqrt(mean_squared_error(y_test, y_pred)))
    print('R2 Score:',r2_score(y_test, y_pred))

# %%
model_name,score,rmse=[],[],[]

# %%
#Linear Regression
lreg=LinearRegression()
models(lreg,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('Linear Regression')
# Out:
# Model Report
# Score: 0.9676825870075805
# RMSE: 7.88785678467851
# R2 Score: 0.35413545340208863

# %%
#Ridge Regression
parameters={'alpha':[0.001,0.01,1]}
best=GridSearchCV(Ridge(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'alpha': 1}

# %%
rr=Ridge(alpha=1)
models(rr,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Ridge Regression')
# Out:
# Model Report
# Score: 0.9367126383299619
# RMSE: 5.43954939654179
# R2 Score: 0.6928508895769742

# %%
#Lasso Regression
parameters={'alpha':[0.001,0.01,1]}
best=GridSearchCV(Lasso(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'alpha': 1}

# %%
lr=Lasso(alpha=1)
models(lr,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Lasso Regression')
# Out:
# Model Report
# Score: 0.8868364338924676
# RMSE: 4.597478076507454
# R2 Score: 0.7805868027961935

# %%
#ElasticNet
enr=ElasticNet(alpha=0.01)
models(enr,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Elastic Net')
# Out:
# Model Report
# Score: 0.9478689675600309
# RMSE: 4.8807263866065576
# R2 Score: 0.7527180962534515

# %%
#Support Vector Regression
parameters={'kernel':['linear','poly','rbf']}
best=GridSearchCV(SVR(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'kernel': 'linear'}

# %%
svr=SVR(kernel='linear')
models(svr,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Support Vector Regression')
# Out:
# Model Report
# Score: 0.9154844011875745
# RMSE: 5.307869322974896
# R2 Score: 0.7075417638431352

# %%
#Decision Tree Regressor Model
parameters={'max_depth':[8,10,12,15],'min_samples_leaf':[100,150]}
best=GridSearchCV(DecisionTreeRegressor(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'max_depth': 8, 'min_samples_leaf': 100}

# %%
dct=DecisionTreeRegressor(max_depth=8,min_samples_leaf=100)
models(dct,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Decision Tree Regression')
# Out:
# Model Report
# Score: 0.0
# RMSE: 9.839576478711026
# R2 Score: -0.005023515021487235

# %%
#Random Forest Regressor
parameters={'n_estimators':[200,300,400],'max_depth':[5,6]}
best=GridSearchCV(RandomForestRegressor(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 200}

# %%
rf=RandomForestRegressor(n_estimators=300,max_depth=5)
models(rf,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Random Forest Regression')
# Out:
# Model Report
# Score: 0.9492187315493851
# RMSE: 6.673898271475579
# R2 Score: 0.5376375279791897

# %%
final=pd.DataFrame({'Model Name':model_name,'Score':score,'RMSE':rmse})
final
# Out:
#                   Model Name     Score      RMSE
# 0          Linear Regression  0.967683  7.887857
# 1           Ridge Regression  0.936713  5.439549
# 2           Lasso Regression  0.886836  4.597478
# 3                Elastic Net  0.947869  4.880726
# 4  Support Vector Regression  0.915484  5.307869
# 5   Decision Tree Regression  0.000000  9.839576
# 6   Random Forest Regression  0.949219  6.673898

# %% [markdown]
# Linear Regression Model performed well

# %%
#save the best model
import joblib
from joblib import dump
joblib.dump(lreg,'Baseball_Dataset.pkl')
# Out:
# ['Baseball_Dataset.pkl']
